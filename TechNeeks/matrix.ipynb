# %% [markdown]
# Python:
#
# * Use NumPy to create at least three matrices.
# * Perform and print:
#   * Matrix addition
#   * Matrix subtraction
#   * Matrix multiplication using np.dot() or the @ operator
#   * Matrix transpose using ".T"
# * Create an identity matrix using "np.eye()".
# * Find the inverse of a valid matrix using "np.linalg.inv()".
# * Experiment with matrices of different dimensions and note which operations are valid and which produce errors.

# %%
import numpy as np

# %%
A = np.array([[1, 2],[3, 4]])

# %%
print("Matrix A:")
print(A)
# Out:
# Matrix A:
# [[1 2]
#  [3 4]]

# %%
B = np.array([[5, 6],[7, 8]])

# %%
print("Matrix B:")
print(B)
# Out:
# Matrix B:
# [[5 6]
#  [7 8]]

# %%
C = np.array([[2, 0],[1, 2]])

# %%
print("Matrix C:")
print(C)
# Out:
# Matrix C:
# [[2 0]
#  [1 2]]

# %% [markdown]
# * OPERATIONS
# 1. A+B
# 2. B-A
# 3. AB (MATRIX MULT.)
# 4. TRANSPOSE OF A AND B
# 5. IDENTITY OF 3X3
# 6. INVERSE OF MATRIX

# %%
# 1.
print(A+B)
# Out:
# [[ 6  8]
#  [10 12]]

# %%
# 2.
print(B-A)
# Out:
# [[4 4]
#  [4 4]]

# %%
# 3.
print(A @ B)
# Out:
# [[19 22]
#  [43 50]]

# %%
# 4.
print(A.T)
print(" ")
print(B.T)
# Out:
# [[1 3]
#  [2 4]]
#
# [[5 7]
#  [6 8]]

# %%
# 5.
print(np.eye(3))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#6
print(np.linalg.inv(A))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
print(np.linalg.inv(B))
# Out:
# [[-4.   3. ]
#  [ 3.5 -2.5]]
